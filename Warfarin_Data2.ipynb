# %% [markdown]
# <a href="https://colab.research.google.com/github/FarahYusri12/Warfarin/blob/main/Warfarin_Data2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('Warfarin_gen_clinic.csv')

# %%
print("Data Information:")
df.info()
# Out:
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5700 entries, 0 to 5699
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       5700 non-null   object
#  1   Age (years)              5658 non-null   object
#  2   Gender                   5696 non-null   object
#  3   Weight (kg)              5413 non-null   float64
#  4   Height (cm)              4554 non-null   float64
#  5   Dose (mg)                5528 non-null   float64
#  6   CYP2C9                   5567 non-null   object
#  7   VKORC1 (rs9923231; C/T)  4046 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 356.4+ KB

# %%
# Create a new subset that consists of ID, Dose, CYP2C9, and VKORC1

df_gen=df[['ID', 'Dose (mg)', 'CYP2C9','VKORC1 (rs9923231; C/T)' ]]
df_gen.head()

#df_gen is the a name for a new subset
# Out:
#             ID  Dose (mg) CYP2C9 VKORC1 (rs9923231; C/T)
# 0  PA135312261       49.0  *1/*1                     A/G
# 1  PA135312262       42.0  *1/*1                     A/A
# 2  PA135312263       53.0  *1/*1                     G/G
# 3  PA135312264       28.0  *1/*1                     A/G
# 4  PA135312265       42.0  *1/*3                     A/G

# %%
print("Data Information:")
df_gen.info()
# Out:
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5700 entries, 0 to 5699
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       5700 non-null   object
#  1   Dose (mg)                5528 non-null   float64
#  2   CYP2C9                   5567 non-null   object
#  3   VKORC1 (rs9923231; C/T)  4046 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 178.3+ KB

# %%
# To export new subset into csv file

file_name_csv='df_gen.csv'
df_gen.to_csv(file_name_csv, index=False)
print(f"Subset of dataframe has been export to '{file_name_csv}'")
# Out:
# Subset of dataframe has been export to 'df_gen.csv'
